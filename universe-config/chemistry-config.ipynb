# %%
import os
import copy
import json
import re
import json
import pickle as pkl
from importlib import reload
from zipfile import ZipFile
from io import BytesIO
from collections import defaultdict

import pandas as pd
import numpy as np

from owlready2 import *
import rdflib

# %%
pc = get_ontology("../../data/PathwayCommons12.reactome.BIOPAX.owl").load()
#pc = get_ontology("../../data/PathwayCommons12.kegg.BIOPAX.owl").load()

# %%
Pathway = list(filter(lambda x: x.name == 'Pathway', pc.world.classes()))[0]
Interaction = list(filter(lambda x: x.name == 'Interaction', pc.world.classes()))[0]
Conversion = list(filter(lambda x: x.name == 'Conversion', pc.world.classes()))[0]
Control = list(filter(lambda x: x.name == 'Control', pc.world.classes()))[0]
Catalysis = list(filter(lambda x: x.name == 'Catalysis', pc.world.classes()))[0]
TemplateReaction = list(filter(lambda x: x.name == 'TemplateReaction', pc.world.classes()))[0]
BiochemicalReaction = list(filter(lambda x: x.name == 'BiochemicalReaction', pc.world.classes()))[0]
BindingFeature = list(filter(lambda x: x.name == 'BindingFeature', pc.world.classes()))[0]
ModificationFeature = list(filter(lambda x: x.name == 'ModificationFeature', pc.world.classes()))[0]
Complex = list(filter(lambda x: x.name == 'Complex', pc.world.classes()))[0]

#list(pc.world.classes())

# %%
def convert_db_name(db):
  if db == 'UniProtKB' or db == 'uniprot knowledgebase':
    return 'uniprot'
  elif db == 'ncbi gene':
    return 'ncbi'
  elif db == 'hgnc symbol':
    return 'hgnc'
  return db.lower()


def convert_db_id(id):
  if ':' in str(id):
    return id.split(':')[-1].lower()
  return str(id).lower()


def make_db_ref(db, id):
  return '{0}:{1}'.format(convert_db_name(db), convert_db_id(id))

def load_gene_info(path):
  """Load the NCBI Gene file and returns a {gene_name: info} dictionary"""
  gene_info = pd.read_csv(path, delimiter='\t')
  gene_info_map = {}
  gene_name_map = {}
  for _, row in gene_info.iterrows():
    info = {
      'name': row['Symbol'],
#       'type': row['type_of_gene'],
#       'desc': row['Other_designations'].split('|')[0],
    }
    ids = [make_db_ref('ncbi', row['GeneID'])]
    gene_name_map[info['name']] = info
    for xref in row['dbXrefs'].split('|'):
      xref_parts = xref.split(':')
      db = xref_parts[0]
      id = xref_parts[-1]
      ids.append(make_db_ref(db, id))
    for id in ids:
      gene_info_map[id] = info
#     for s in row['Synonyms'].split('|'):
#       gene_info_map[s] = info
  return gene_info, gene_info_map, gene_name_map

gene_info, gene_info_map, gene_name_map = load_gene_info('../../data/Mus_musculus.gene_info')

# %%
def parse_molecule(m):
  res = {
    'type': 'molecule',
    'name': m.displayName if m.displayName is not None else m.name,
#     'name': getattr(m, 'displayName', m.name),
#     'name': m.name,
  }
  if isinstance(m, Complex):
    res['type'] = 'complex'
    res['component'] = [parse_molecule(cc) for cc in m.component]
  if hasattr(m, 'cellularLocation') and m.cellularLocation is not None:
    if len(m.cellularLocation.term) > 0:
      res['cellularLocation'] = m.cellularLocation.term[0]
      #print('cellularLocation', res['cellularLocation'])
#   if hasattr(m, 'feature') and m.feature is not None:
#     res['feature'] = []
#     if len(m.feature) > 0:
#       for f in m.feature:
#         if not isinstance(f, ModificationFeature) and not isinstance(f, BindingFeature):
#           continue
#         feature = {
#           'biopaxType': str(f.__class__).replace('biopax-level3.', ''),
#         }
#         if hasattr(f, 'modificationType') and f.modificationType is not None:
#           feature['modificationType'] = f.modificationType.term[0]
#         if hasattr(f, 'featureLocation') and f.featureLocation is not None:
#           feature['featureLocation'] = [{
#             'sequencePosition': l.sequencePosition,
#             'positionStatus': l.positionStatus,
#           } for l in f.featureLocation]
# #         print(f.get_properties())
# #         print(f.modificationType.term[0])
# #         print(f.featureLocation[0].get_properties())
# #         print(f.featureLocation[0].sequencePosition)
# #         print(f.featureLocation[0].positionStatus)
# # #         print(f.comment)
# #         print(f.featureLocation)
# #         print(f.modificationType.term[0])
#         res['feature'].append(feature)
  if hasattr(m, 'entityReference') and m.entityReference is not None:
    e = m.entityReference
    res['entityReference'] = {
      'name': getattr(e, 'displayName', e.name),
    }
    if hasattr(e, 'xref') and e.xref is not None:
      for x in e.xref:
        if x.db is None:
          continue
        conv_id = '{0}:{1}'.format(convert_db_name(x.db), convert_db_id(x.id))
#         if conv_id in all2mouse:
#           for db_ref in all2mouse[conv_id]:
#             if db_ref in gene_info_map:
#               res['entityReference']['gene'] = gene_info_map[db_ref]
        if 'gene' not in res['entityReference']:
          if res['entityReference']['name'] in gene_name_map:
            res['entityReference']['gene'] = gene_name_map[res['entityReference']['name']]
          elif res['name'] in gene_name_map:
            res['entityReference']['gene'] = gene_name_map[res['name']]
        
        # TODO: resolve small molecules
        if ('uniprot' in x.db) \
          or ( \
            (x.db == 'ensembl' or x.db == 'ncbi gene') \
            and ( \
              'xref' not in res['entityReference'] \
              or res['entityReference']['xref']['db'] != 'ncbi gene' \
            ) \
          ) \
          or ( \
#             x.db in ['chebi'] \
#             and 
            'xref' not in res['entityReference'] \
          ):
          # NCBI Gene has the top priority and the Ensemlb goes next
          res['entityReference']['xref'] = {
            'id': convert_db_id(x.id),
            'db': convert_db_name(x.db),
          }
#       res['entityReference']['xref'] = [
#         {
#           'id': x.id,
#           'db': x.db,
# #           'relationshipType': [
# #              r.term
# #             for r in getattr(x, 'relationshipType', [])
# #           ],
#         }
#         for x in e.xref
#       ]
#     if hasattr(e, 'organism') and e.organism is not None:
#       o = e.organism
#       res['entityReference']['organism'] = {
#         'name': getattr(o, 'displayName', o.name),
#       }
#       if 'Homo' not in res['entityReference']['organism']['name']:
#         print(res['entityReference']['organism']['name'])
  return res


def parse_reaction(r):
  res = {
    'type': 'reaction',
    'name': r.displayName if r.displayName is not None else r.name,
#     'name': getattr(r, 'displayName', r.name),
#     'comment': getattr(r, 'comment', None),
    'conversionDirection': getattr(r, 'conversionDirection', None),
  }
  if hasattr(r, 'left') and r.left is not None:
    res['left'] = [parse_molecule(c) for _, c in enumerate(r.left)]
  if hasattr(r, 'right') and r.right is not None:
    res['right'] = [parse_molecule(c) for _, c in enumerate(r.right)]
  return res


def parse_control(c):
  res = {
    'type': 'control',
    'name': c.displayName if c.displayName is not None else c.name,
#     'name': getattr(c, 'displayName', c.name),
#     'comment': getattr(c, 'comment', None),
    'controlType': getattr(c, 'controlType', None),
  }
  if hasattr(c, 'controller') and c.controller is not None:
    res['controller'] = [parse_molecule(cc) for cc in c.controller]
  if hasattr(c, 'cofactor') and c.cofactor is not None:
    res['cofactor'] = [parse_molecule(cc) for cc in c.cofactor]
  if hasattr(c, 'controlled') and c.controlled is not None:
    res['controlled'] = parse_reaction(c.controlled)
  return res


def parse_template_reaction(c):
  res = {
    'type': 'template_reaction',
    'name': c.displayName if c.displayName is not None else c.name,
#     'name': getattr(c, 'displayName', c.name),
#     'comment': getattr(c, 'comment', None),
    'templateDirection': getattr(c, 'templateDirection', None),
  }
  if hasattr(c, 'template') and c.template is not None:
    res['template'] = parse_molecule(c.template)
  if hasattr(c, 'product') and c.product is not None:
    res['product'] = [parse_molecule(cc) for cc in c.product]
  return res


parsed_pathway_steps = {}
def parse_pathway_step(s):
  reactions = []
  if s.name in parsed_pathway_steps:
    # Avoid infinite recursions
    return reactions
  parsed_pathway_steps[s.name] = ''
  res = {
    'type': 'pathway_step',
    'name': s.displayName if s.displayName is not None else s.name,
#     'name': getattr(c, 'displayName', c.name),
#     'comment': getattr(c, 'comment', None),
    'stepDirection': getattr(s, 'stepDirection', None),
  }
  if hasattr(s, 'stepConversion') and s.stepConversion is not None:
    res['stepConversion'] = parse_reaction(s.stepConversion)
    reactions.append(res['stepConversion'])
  if hasattr(s, 'stepProcess') and s.stepProcess is not None:
    res['stepProcess'] = [parse_control(cc) for cc in s.stepProcess]
    reactions.extend(res['stepProcess'])
  if hasattr(s, 'nextStep') and s.nextStep is not None:
    for ss in s.nextStep:
      reactions.extend(parse_pathway_step(ss))
  return reactions

def parse_pathway(p):
  res = {
    'type': 'pathway',
    'name': getattr(p, 'displayName', p.name),
#     'comment': getattr(p, 'comment', None),
  }
  if hasattr(p, 'pathwayComponent') and p.pathwayComponent is not None:
    res['pathwayComponent'] = []
    for c in p.pathwayComponent:
      if isinstance(c, Pathway):
#         res_list.append(parse_pathway(c))
        continue
      elif isinstance(c, Control):
        res['pathwayComponent'].append(parse_control(c))
      elif isinstance(c, TemplateReaction):
        res['pathwayComponent'].append(parse_template_reaction(c))
      else:
        res['pathwayComponent'].append(parse_reaction(c))
  
  if hasattr(p, 'pathwayOrder') and p.pathwayOrder is not None:
    if 'pathwayComponent' not in res:
      res['pathwayComponent'] = []
    for s in p.pathwayOrder:
      res['pathwayComponent'].extend(parse_pathway_step(s))

  return res


# print(list(pc.world.properties()))

parsed_map = {}
pathways = []

generic_pathway_template = {
  'type': 'pathway',
  'name': '<generic>',
  'pathwayComponent': [],
}

def process_reactions(reaction_class, parse_fn):
  print(len(reaction_class.instances()))
  for c in reaction_class.instances()[:]:
    if c.name in parsed_map:
      continue
    parsed_map[c.name] = ''
#     for xref in c.xref:
#       print(xref.title)
#       print(xref.get_properties())
    r = parse_fn(c)
    generic_pathway = copy.deepcopy(generic_pathway_template)
    generic_pathway['pathwayComponent'].append(r)
    pathways.append(generic_pathway) 

for reaction_class, parse_fn in [
  (Control, parse_control),
  (TemplateReaction, parse_template_reaction),
  (BiochemicalReaction, parse_reaction),
  (Conversion, parse_reaction),
#   (Interaction, parse_reaction),
]:
  process_reactions(reaction_class, parse_fn)

# for p in Pathway.instances()[:]:
#   pathway = parse_pathway(p)
# #   print(json.dumps(res, indent=2)[:100000])
#   pathways.append(pathway)

print(len(pathways))
# Out:
# 7425
# 14
# 12184
# 12201
# 19640

# %%
def match_participant(m, query):
  if m['type'] == 'complex':
    return any([match_participant(c, query) for c in m['component']])
  if query.lower() in m['name'].lower():
    return True
  return False

def filter_pathways_by_participant(query):
  filtered_pathways = []
  for p in pathways:
    filtered_p = copy.deepcopy(p)
    filtered_p['pathwayComponent'] = []
    for r in p['pathwayComponent']:
      matched = False
      rr = r
      if r['type'] == 'control':
        for m in r['controller']:
          matched = matched or match_participant(m, query)
        for m in r['cofactor']:
          matched = matched or match_participant(m, query)
      elif r['type'] == 'template_reaction':
        for m in r['product']:
          matched = matched or match_participant(m, query)
      if 'left' in rr:
        for m in rr['left']:
          matched = matched or match_participant(m, query)
      if 'right' in rr:
        for m in rr['right']:
          matched = matched or match_participant(m, query)
    if matched:
      filtered_p['pathwayComponent'].append(r)
    if len(filtered_p['pathwayComponent']) > 0:
      filtered_pathways.append(filtered_p)
  return filtered_pathways

filtered_pathways = filter_pathways_by_participant('ca2+')
print(len(filtered_pathways))
print(json.dumps(list(map(lambda p: p['pathwayComponent'][0]['name'], filtered_pathways)), indent=2))
#print(json.dumps(list(map(lambda p: p['pathwayComponent'][0]['controlled']['name'], filtered_pathways)), indent=2))
#print(json.dumps(filtered_pathways[:5], indent=2))

# https://reactome.org/PathwayBrowser/#/R-HSA-163200&SEL=R-HSA-163213&PATH=R-HSA-1430728,R-HSA-1428517
# https://reactome.org/PathwayBrowser/#/R-HSA-163200&SEL=R-HSA-163214&PATH=R-HSA-1430728,R-HSA-1428517

# for p in pathways:
#   for r in p['pathwayComponent']:
#     print(r['name'])
#     break
#     if 'R11945' in r['name']:
#       print(r)
# Out:
# 339
# [
#   "R-HSA-158645",
#   "R-HSA-5336160",
#   "R-HSA-5607785",
#   "R-HSA-2648999",
#   "R-HSA-2730672",
#   "R-HSA-5358685",
#   "R-HSA-2684957",
#   "R-HSA-111972",
#   "R-HSA-3229230",
#   "R-HSA-5607784",
#   "R-HSA-5607787",
#   "R-HSA-5610119",
#   "R-HSA-8857690",
#   "R-HSA-5333036",
#   "Control_92e7377f8c17b64a542bbdb675a3fe12",
#   "R-HSA-1489501",
#   "R-HSA-1663719",
#   "R-HSA-9034483",
#   "R-HSA-5336148",
#   "R-HSA-9015052",
#   "Control_0f0070d86be5ad0b29e8311d985db98c",
#   "R-HSA-158643",
#   "R-HSA-977428",
#   "R-HSA-210503",
#   "Control_0224ec86f778e7febf2593ac5ddcc3b0",
#   "R-HSA-5333034",
#   "R-HSA-2855230",
#   "R-HSA-5211366",
#   "R-HSA-9034487",
#   "R-HSA-5626550",
#   "R-HSA-3223249",
#   "R-HSA-5607786",
#   "R-HSA-9034486",
#   "R-HSA-9034527",
#   "R-HSA-8876920",
#   "Control_656defa0440dd838b21dca1ca1196c61",
#   "R-HSA-71589",
#   "R-HSA-71542",
#   "R-HSA-2744259",
#   "R-HSA-6809098",
#   "R-HSA-8848729",
#   "R-HSA-3223247",
#   "R-HSA-5607091",
#   "R-HSA-2889054",
#   "R-HSA-9015053",
#   "Catalysis_33509413b4323e37244bb4583dcb65c9",
#   "Catalysis_a3f81fcffccdffe3bc33b1e092ff5af9",
#   "Catalysis_7481cae835c2e9d26d1f05f8dce63a4d",
#   "Catalysis_b8bd2880463202b778105e4a54a7c390",
#   "Catalysis_717745cedecdbcbabc71fba90cd9b352",
#   "Catalysis_48cd98212cd23ca1d052f05716cd8bbd",
#   "Catalysis_52d074e2708109ed2d72d5af8f0caba0",
#   "Catalysis_acb9217e6b0fd16f6dacd8af24923e3d",
#   "Catalysis_f17d3e17aaa9f4da57ed540c34048c87",
#   "Catalysis_6f3133eef0abe6b6cdaabc45eb5bc17d",
#   "Catalysis_910a33f75144aebc93215024e0394424",
#   "Catalysis_c5e184a642ef1673ce038fcaf278cba5",
#   "Catalysis_006a4404c144cd493090712faff1dac4",
#   "Catalysis_7ed7f71c5b59181addd9243e2c607d20",
#   "Catalysis_bd30e0601e9609171d8c2164cc514687",
#   "Catalysis_2011edeb5d01078f4211795062e7abf5",
#   "Catalysis_635fd1bf0d6a778e90df26d1bcef466e",
#   "Catalysis_6d38755eb412c0c8b0deebfecee03ae6",
#   "Catalysis_1cbd28e66a8f6cead8fa86f2b9c87f6b",
#   "Catalysis_f0989fcbfa9b52f844baab35334b2864",
#   "Catalysis_83a26e2011459cc136d07b3cc5fada26",
#   "Catalysis_fb7b3a6d2f7f582d3f7459e3fef2e62c",
#   "Catalysis_36b7df0ca3ddb2c0522385a138135cef",
#   "Catalysis_ba770f1d279683b55464723fa90b23f3",
#   "Catalysis_c057bfd7b3ca012212c4021192850933",
#   "Catalysis_915bd2bddb62f33af6c716cfe2a2da50",
#   "Catalysis_0bcb426f62204035f9a004843803cb04",
#   "Catalysis_e53aef662e271e791842408bd69ef301",
#   "Catalysis_fbb03456471b0d3f7def6a141db3dfe3",
#   "Catalysis_17560a6f06a9b07d5921c9dd913a7a18",
#   "Catalysis_b478e20709ab732143fefd18687d4a81",
#   "Catalysis_f2a2505bab5f407694e6f8a0f683f675",
#   "Catalysis_e341f6b1d3ddda5a083ba77429ee0760",
#   "Catalysis_e02489ac2806a416128b257ec0248ad1",
#   "Catalysis_1002d0b349d1db3a361727dd405ac74d",
#   "Catalysis_6d1b28361ac81229cdb48a6926622bff",
#   "Catalysis_63859491b32f693ad2bac3ef92227333",
#   "Catalysis_dcec3acda3c6c958349ce5d4887a7f31",
#   "Catalysis_ca4c2b90ced928f3342033ba2ded919f",
#   "Catalysis_2e668f8cc64372c032f5ebd6e16d32fd",
#   "Catalysis_3bd6c3e04760b674b8560e36518629e0",
#   "Catalysis_e436cc65222cbb1d0b1f76183d06084e",
#   "Catalysis_c6518a147bb17d032d20ffe427f6e7a8",
#   "Catalysis_e57d14355ec30b5660f14245e806759c",
#   "Catalysis_7468ee7b146986f9a26ace049a2dcaf7",
#   "Catalysis_c57ed00228d3424283730adeda4ec26e",
#   "Catalysis_7327506e8775fe06b777d8f52bf275cf",
#   "Catalysis_2ac170138cdaa9eee094f2ee7893bb41",
#   "Catalysis_7a7a702185363231e0b6a9974058d4ed",
#   "Catalysis_ed4914a3c48c7d7075f77856c5186c44",
#   "Catalysis_56d646996ebe5cd4ae879538c5c5badc",
#   "Catalysis_63e43081b7ef7419b999e89a8c53c0f3",
#   "Catalysis_c1d552c407575b892f2144ae974f077e",
#   "Catalysis_f3ff1807d287ad6d69738f5184df3b8d",
#   "Catalysis_adc9b289df04519db1f893c035aaa190",
#   "Catalysis_10dd73c0908f4fee7f88af3d621d46dd",
#   "Catalysis_125c5a9d3ac58e8a2fb55268c223669f",
#   "Catalysis_3f122a7c066498ad13489f795bb37d28",
#   "Catalysis_64e493d558049e4736b97af2e67132ce",
#   "Catalysis_0cb7806bfe4840b361ee5d6505e86dea",
#   "Catalysis_c2d38bfa951a078632369d3c12e7ab15",
#   "Catalysis_ad52fa185f218bc5e14e44e0947e6b0a",
#   "Catalysis_18a6a7b43af0583129fe07e1cb7b5d26",
#   "Catalysis_c795a9b209111948f911c2259a25309c",
#   "Catalysis_11519970180d7235e0584dc438ab133a",
#   "Catalysis_e9f7167590e735a38e93a4b9a06b33c5",
#   "Catalysis_d1bdc360c0e2af43d245560983dc8b90",
#   "Catalysis_8c3e2ed5c8838ae7ce699e17727e3e20",
#   "Catalysis_2cef99889ad4ad241f2abf1c32084548",
#   "Catalysis_6be46eeb1ecff283736b329e0970004e",
#   "Catalysis_b77933bae383327826536179f2d25d42",
#   "Catalysis_f856ecf184c2936842566f3e319159cf",
#   "Catalysis_903811ba9da4a3fcb2c080d2b1353473",
#   "Catalysis_afb0b0b21ee69aa90e341ada8a20a73b",
#   "Catalysis_0a92f9fc7f1f965dca4699434c3346d9",
#   "Catalysis_b1c8f06a634948a4793ebfc43cc547f5",
#   "Catalysis_61ec17c7e9d636a6e70ed622c1d8641f",
#   "Catalysis_efbf5ec5edad5c0611364d8b2521a7a7",
#   "Catalysis_88964d26a5ccaf8b5bf54993e074d46c",
#   "Catalysis_abcb89108bb1be3bcc6966a069dbb8ac",
#   "Catalysis_2131384ae82c61e79d5bb261cc30e1c6",
#   "Catalysis_dd8187a3095b30b282b50ef27f2178ff",
#   "Catalysis_5ac9e145bf9bfddab11ccc3932c30c61",
#   "Catalysis_7455600125aaba997296e6051270c31a",
#   "Catalysis_b7dfe873db3d6b4b470ca7f65c6493cb",
#   "Catalysis_5e05e18945598befa684d8747d7c7510",
#   "Catalysis_97ef44a47d40595c3a2a625a23c448cb",
#   "Catalysis_51dbf04f405ddb1c0e752b713ccc9fb6",
#   "Catalysis_e24b6e60e1e375de805a38cf7423673d",
#   "Catalysis_31608980d1cc5e71fc37bfe4e5425b03",
#   "Catalysis_1f3d2b1063ac7f1e8d9a771cfc644ae2",
#   "Catalysis_895247441a612ba119b019eb4c6edee3",
#   "Catalysis_f00fb05179a9be205824c25eb64a7ba3",
#   "Catalysis_0f45c9af5c7ddbb6f9ffbc9383d379df",
#   "Catalysis_56a17e76c27e50a9a1d7d8d9ea7557ad",
#   "Catalysis_c3999f288f716e467bedd50ab129cdbc",
#   "Catalysis_c2182e9d70b6a4ae128bce87b97741ff",
#   "Catalysis_f4b90b40e2a4cd3163c0b657e2acdd64",
#   "Calcium binds calmodulin at the synapse",
#   "PPM1F dephosphorylates p-T286-CaMKII",
#   "Exocytosis of Insulin",
#   "E-cadherin degradation by ADAM10, ADAM15",
#   "factor V -> factor Va + factor V activation peptide",
#   "Activation of Ca permeable AMPA receptors",
#   "Decreasing cGMP concentration promotes intracellular Ca2+ release in response to WNT",
#   "CaMKII autophosphorylates",
#   "Activated calmodulin binds ADCY1,ADCY8",
#   "TPCN1/2 transport lysosomal Ca2+ to cytosol",
#   "CALM1:4xCa2+ binds GluN1:GluN2 (GRIN1:GRIN2) NMDA receptors and displaces ACTN2",
#   "PPM1F dephosphorylates CAMK1",
#   "PPM1E dephosphorylates CAMK4",
#   "SPARC binds Collagen type I fibril, hydroxylapatite and Ca2+",
#   "thrombin:cleaved antithrombin III:heparin -> thrombin:cleaved antithrombin III + heparin",
#   "Dissociation of CaM and CAMK2 autophosphorylation",
#   "G-protein subunits dissociate from WNT:FZD complex",
#   "WNT5A and WNT11 bind FZD receptors to initiate Ca2+ signaling",
#   "WNT:FZD complex promotes G-protein nucleotide exchange",
#   "FZD recruits trimeric G-proteins",
#   "Autophosphorylation and activation of CAMK2",
#   "Translocation of NFATC1:CaN:CaM to nucleus",
#   "Active calmodulin binds CAMK2",
#   "Translocation and activation of PKC alpha in response to WNT signaling",
#   "Calcineurin binds and dephosphorylates NFAT1 in response to WNT/Ca2+ signaling",
#   "Activation of Calcineurin",
#   "SERPINA5 binds activated protein C",
#   "S100A8:S100A9:AA:Ca(2+) binds NOX2 complex",
#   "S100A8:S100A9 binds Mn2+",
#   "Activated calmodulin dissociates from CaMKII-gamma",
#   "Calcium Influx through Voltage-gated Calcium Channels",
#   "Activation of Ca-permeable Kainate receptors",
#   "CAMK4 autophosphorylates",
#   "Protease nexin-1 (PN1) is a specific and extremely efficient inhibitor of thrombin.",
#   "Insulin secretory granule translocates to cell cortex",
#   "Proinsulin:Zinc:Calcium complex translocates to immature secretory granule",
#   "SLC24A1 exchanges 4Na+ for Ca2+, K+",
#   "Proinsulin binds zinc and calcium forming Proinsulin:zinc:calcium",
#   "Calcium-sensing receptor binds calcium",
#   "CaMKKs phosphorylate CAMK1",
#   "Ca2+ influx through voltage gated Ca2+ channels",
#   "CaMKII binds activated calmodulin",
#   "CaMKK autophosphorylates in the nucleus",
#   "p-T287-CAMK2G:CALM1:4xCa2+ enters nucleus",
#   "Calmodulin binds CAMK4",
#   "CaMKK phosphorylates CAMK4",
#   "CaMKK binds activated calmodulin in the nucleus",
#   "Activation of RasGRF",
#   "PA63:ANTRX1 oligomer transports EF and LF (target cell endosome to cytosol)",
#   "Endocytosis of EF:LF:PA63:ANTXR2 (plasma membrane to endosome membrane)",
#   "ANTXR2-bound PA63 forms oligomers",
#   "PA83 binds ANTXR1",
#   "PA83 binds ANTXR2",
#   "Furin cleaves ANTXR2-bound PA83 to yield PA63",
#   "ANTXR1-bound PA63 forms oligomers",
#   "EF and LF bind to PA63:ANTXR2 oligomer",
#   "EF and LF bind to PA63:ANTXR1 oligomer",
#   "Furin cleaves ANTXR1-bound PA83 to yield PA63",
#   "PA63:ANTRX2 oligomer transports EF and LF (target cell endosome to cytosol)",
#   "Endocytosis of EF:LF:PA63:ANTXR1 (plasma membrane to endosome membrane)",
#   "CL-LK binds carbohydrates on target cell surface",
#   "SLC8A3 (NCX3) exchanges sodium (cytosol) for calcium (mitochondrial intermembrane space)",
#   "Insulin secretory granule translocates across the cortical actin network",
#   "Carboxypeptidase E cleaves Insulin(25-56) to yield Insulin(25-54)",
#   "PCSK1 cleaves proinsulin to yield Insulin(25-56) and Insulin(57-110)",
#   "PCSK2 cleaves Insulin(57-110) to yield Insulin(90-110) and C-peptide (Insulin(57-89))",
#   "Insulin secretory granule docks at the plasma membrane",
#   "Transport of Ca++ from platelet dense tubular system to cytoplasm",
#   "Binding of IP3 to IP3 receptor",
#   "Calcium and Diacylglycerol activate CalDAG-GEFs (RasGRPs)",
#   "Hyaluronidase 2 (HYAL2) hydrolyses HA into 20kDa fragments",
#   "S100A8:S100A9 binds Zn2+",
#   "S100A7/S100A15 binds Zn2+",
#   "GRK2 binds CALM1:4Ca2+",
#   "SERPIND1 binds activated thrombin (factor IIa)",
#   "CALM1:Ca2+ binds CNG channel",
#   "Calcium influx via CRAC",
#   "activation of factor VII",
#   "VDAC1,2,3 translocate calcium from the cytosol to the mitochondrial intermembrane space",
#   "p-AKT2 phosphorylates C2CD5",
#   "prothrombin -> activated thrombin (factor IIa) + thrombin activation peptide (Xa catalyst)",
#   "activation of factor X by TF:F7a",
#   "Protein Kinase C beta (PKC-beta, PRKCB) is activated",
#   "LTCC heteropentamer (open) transports Ca2+ from extracellular region to cytosol",
#   "Activation of conventional Protein Kinase C",
#   "protein C -> activated protein C + protein C heavy chain activation peptide",
#   "Phospho-cPLA2 translocates to membranes when intracellular calcium levels increase",
#   "Calcium binds calmodulin",
#   "MCU translocates calcium from the mitochondrial intermembrane space to the mitochondrial matrix",
#   "SLC8B1 (NCLX) exchanges sodium (mitochondrial intermembrane space) for calcium (mitochondrial matrix)",
#   "LETM1 exchanges protons (mitochondrial intermembrane space) for calcium (mitochondrial matrix)",
#   "Ficolin-3 binds to molecular patterns on the target cell surface",
#   "activation of factor X by VIIIa:IXa",
#   "STIM1 oligomerizes",
#   "TRPs transport extracellular Ca2+ to cytosol",
#   "Translocation of CaN:CaM:NFAT to nucleus",
#   "prothrombin -> activated thrombin (factor IIa) + thrombin activation peptide (prothrombinase catalyst)",
#   "activation of factor X by TF:F7",
#   "formation of TF:F7 complex",
#   "formation of TF:F7a complex",
#   "Inactivation of factor VIIa by TFPI",
#   "Calcium Binds Caldesmon",
#   "Myosin Binds ATP",
#   "ATP Hydrolysis By Myosin",
#   "MYLK (MLCK) Active Calmodulin Binding",
#   "Release Of ADP From Myosin",
#   "Calcineurin dephosphorylates NFATC1,2,3",
#   "Calcineurin binds NFATC1,2,3",
#   "SLC24A5 exchanges cytosolic 4Na+ for Golgi luminal Ca2+, K+",
#   "DAG and Ca+2 bind to PKC and tether it to membrane",
#   "Activated protein C binds Protein S",
#   "RYR tetramers transport Ca2+ from sarcoplasmic reticulum lumen to cytosol",
#   "RCVRN:Ca2+ binds to and inhibits GRK1",
#   "CALB1 binds 4xCa2+",
#   "cGMP:CNG transports Na+ and Ca2+ into the rod outer segment",
#   "Factor IIa inhibitors (peptide) binds IIa",
#   "Calcium Influx via TRPC1",
#   "factor Va + factor Xa -> Va:Xa complex (prothrombinase)",
#   "SLC24A1-4 exchange extracellular 4Na+ for cytosolic Ca2+, K+",
#   "ATP2C1/2:Mg2+ transport cytosolic Ca2+ to Golgi lumen",
#   "Connection of adjacent cells through calcium-dependent trans-dimerization of cadherin",
#   "E-cadherin degradation by MMP9, KLK7",
#   "E-cadherin degradation by PS1:NCSTN (Gamma-secretase)",
#   "AKT1 phosphorylates eNOS",
#   "The cofactor BH4 is required for electron transfer in the eNOS catalytic cycle",
#   "eNOS:Caveolin-1 complex binds to CaM",
#   "HSP90 binds eNOS:Caveolin-1:CaM complex",
#   "AKT1 binds eNOS complex via HSP90",
#   "Caveolin-1 dissociates from eNOS:CaM:HSP90 complex",
#   "IP3R:I(1,4,5)P3 tetramer transports Ca2+ from ER lumen to cytosol",
#   "Influx of extracellular calcium",
#   "Calpain activation",
#   "BH2 binding can lead to eNOS uncoupling",
#   "K+-independent Li+/Ca2+ exchanger transport",
#   "SLC8A1,2,3 exchange 3Na+ for Ca2+",
#   "Defective SLC24A5 does not exchange cytosolic 4Na+ for Golgi luminal Ca2+, K+",
#   "PMCA extrusion of Ca2+",
#   "CaMKII binds activated NMDA receptor",
#   "thrombin:antithrombin III:heparin -> thrombin:cleaved antithrombin III:heparin",
#   "GUCA binds Ca2+ to form GUCA:Ca2+",
#   "Proteinase-activated receptors can bind thrombin",
#   "S100A1 binds TLR4:LY96",
#   "P2X1-mediated entry of Ca++ from plasma",
#   "Sequestration of Ca2+ to dense tubular network lumen",
#   "Myosin Binds ATP",
#   "Inactive catalytic PP2B is activated by the binding of calmodulin",
#   "ATP Hydrolysis By Myosin",
#   "Active ARSA translocates to the lysosome",
#   "Thrombin binding to GP1b:IX:V",
#   "Defective SLC24A1 does not exchange extracellular 4Na+ for cytosolic Ca2+, K+",
#   "Defective SLC24A4 does not exchange extracellular 4Na+ for cytosolic Ca2+, K+",
#   "INTL1 binds bacterial glycans",
#   "HA:HAR:HYAL2 binds to SLC9A1:p-CHP:Ca2+",
#   "Serum amyloid P-component forms homopentamers",
#   "E-cadherin degradation by caspase-3 and calpain-1",
#   "CAMK1 binds calmodulin",
#   "Activated protein C is released from PROCR",
#   "IQGAP1 binds CDH1:CTTNB1:CTTNA1 and MEN1",
#   "IQGAPs bind CALM1",
#   "Calcineurin binds and dephosphorylates NFAT",
#   "Factor Xa inhibitors bind Va:Xa",
#   "Ca2+ influx into the post-synaptic cell",
#   "Activated protein C:PROCR binds F2R",
#   "MBL binds to repetitive carbohydrate structures on the surfaces of viruses, bacteria, fungi, and protozoa",
#   "E-cadherin degradation by MMP3, MMP7 and plasmin.",
#   "Calcium Binds Troponin-C",
#   "Soluble PROCR binds activated protein C",
#   "RasGRP interacts with DAG and Ca2+",
#   "HTR3 pentamer:5HT transports Na+,K+, and Ca2+",
#   "CatSper Channel Mediated Calcium Transport",
#   "Activation of highly calcium permeable nicotinic acetylcholine receptors",
#   "Factor IIa inhibitors (compounds) binds IIa",
#   "CD209 binds ICAM3",
#   "activated thrombin (factor IIa) + thrombomodulin -> activated thrombin:thrombomodulin",
#   "Activation of highly calcium permeable postsynaptic nicotinic acetylcholine receptors",
#   "CBLL1 binds SRC-phosphorylated CDH1 complex",
#   "Sequestration of Ca2+ to intracellular stores",
#   "CBLL1 ubiqutinates the InlA-bound CDH1 complex",
#   "CACFD1 dimer transports Ca2+ from extracellular region to cytosol",
#   "PLA2G2A binds bacterial phospholipids",
#   "SRC phosphorylates InlA-bound CDH1 and CTNNB1",
#   "Ficolin-1 binds to molecular patterns on the target cell surface",
#   "Release Of ADP From Myosin",
#   "Ficolin-2 binds to molecular patterns on the target cell surface",
#   "ALOX5 is phosphorylated by MAPKAP2",
#   "CaMKK autophosphorylates in the cytosol",
#   "InlA binds CDH1",
#   "CaMKK binds activated calmodulin in the cytosol",
#   "Formation of serum amyloid P decamer",
#   "Serum amyloid P binds DNA and chromatin",
#   "Amyloid fibrils have additional components",
#   "factor Va -> factor Vi",
#   "Factor Xa inhibitors binds Xa",
#   "DAG and Ca+2 bind to PKC and tether it to membrane",
#   "factor XIII cleaved tetramer + 2 Ca++ -> factor XIIIa + 2 factor XIII B chain",
#   "activated thrombin (factor IIa) + antithrombin III:heparin -> thrombin:antithrombin III:heparin"
# ]

# %%
import Bio.Data.CodonTable

# %%
(Bio.Data.CodonTable.standard_dna_table).forward_table
# Out:
# {'TTT': 'F',
#  'TTC': 'F',
#  'TTA': 'L',
#  'TTG': 'L',
#  'TCT': 'S',
#  'TCC': 'S',
#  'TCA': 'S',
#  'TCG': 'S',
#  'TAT': 'Y',
#  'TAC': 'Y',
#  'TGT': 'C',
#  'TGC': 'C',
#  'TGG': 'W',
#  'CTT': 'L',
#  'CTC': 'L',
#  'CTA': 'L',
#  'CTG': 'L',
#  'CCT': 'P',
#  'CCC': 'P',
#  'CCA': 'P',
#  'CCG': 'P',
#  'CAT': 'H',
#  'CAC': 'H',
#  'CAA': 'Q',
#  'CAG': 'Q',
#  'CGT': 'R',
#  'CGC': 'R',
#  'CGA': 'R',
#  'CGG': 'R',
#  'ATT': 'I',
#  'ATC': 'I',
#  'ATA': 'I',
#  'ATG': 'M',
#  'ACT': 'T',
#  'ACC': 'T',
#  'ACA': 'T',
#  'ACG': 'T',
#  'AAT': 'N',
#  'AAC': 'N',
#  'AAA': 'K',
#  'AAG': 'K',
#  'AGT': 'S',
#  'AGC': 'S',
#  'AGA': 'R',
#  'AGG': 'R',
#  'GTT': 'V',
#  'GTC': 'V',
#  'GTA': 'V',
#  'GTG': 'V',
#  'GCT': 'A',
#  'GCC': 'A',
#  'GCA': 'A',
#  'GCG': 'A',
#  'GAT': 'D',
#  'GAC': 'D',
#  'GAA': 'E',
#  'GAG': 'E',
#  'GGT': 'G',
#  'GGC': 'G',
#  'GGA': 'G',
#  'GGG': 'G'}

# %%
mol_data = []
type_id = 0

mol_data.extend([
  {
    'type': type_id + 0,
    'category': 'lipid',
    'name': 'Generic lipid',
    'radius': 0.0025,
  },
  {
    'type': type_id + 1,
    'category': 'protein',
    'name': 'Generic protein',
    'radius': 0.0025,
  }
])

type_id = 100
# Generic RNA codons
mol_data.extend([
  {
    'type': type_id + i,
    'category': 'rna',
    'name': codon,
    'radius': 0.00075,
  }
  for i, (codon, amino_acid) in enumerate(Bio.Data.CodonTable.standard_dna_table.forward_table.items())
])
type_id += len(Bio.Data.CodonTable.standard_dna_table.forward_table)

# Start/stop RNA codons
mol_data.extend([
  {
    'type': type_id + i,
    'category': 'rna',
    'name': codon,
    'radius': 0.00075,
  }
  for i, codon in enumerate(Bio.Data.CodonTable.standard_dna_table.start_codons + Bio.Data.CodonTable.standard_dna_table.stop_codons)
])

# Write to a file
with open('./gen/large-molecules.json', 'wt') as f:
  f.write(json.dumps(mol_data, indent=2))
